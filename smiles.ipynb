# %% [markdown]
# <a href="https://colab.research.google.com/github/dh4n4njay/Day1/blob/main/smiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This is day one, hopefully one of many where I try and learn new Computational Chemistry techniques.
# ---
# **Lets go through with it**
#
# Everything that I do here will be available at my personal [github](https://github.com/dh4n4njay) account.
#
#
# Today I am going to learn about SMILES notation, and I will be attaching the resources to learn at the end of this notebook. There might be a lot of text (notes), please try and keep up.

# %% [markdown]
# **Rule 1, 2**: Atomic Symbols and Bonds \-   \=   ≡ \.

# %%
# !pip install rdkit

# %%
from rdkit import Chem
from rdkit.Chem import Draw
mol = Chem.MolFromSmiles('CCCC')
# Display the molecule
img = Draw.MolToImage(mol)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol2 = Chem.MolFromSmiles('CC=CC')
img2 = Draw.MolToImage(mol2)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol3=Chem.MolFromSmiles('CCC#N')
img3= Draw.MolToImage(mol3)
display(img3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol4 = Chem.MolFromSmiles('C[Br]')
img4 = Draw.MolToImage(mol4)
display(img4)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_branch1=Chem.MolFromSmiles('CC(C)CC(=O)CC(#N)')
img_branch1=Draw.MolToImage(mol_branch1)
display(img_branch1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_n=Chem.MolFromSmiles('c1c(N(=O)=O)cccc1')
img_n=Draw.MolToImage(mol_n)
display(img_n)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ## **Day2: Rings and Charged Molecules/Atoms**

# %%
mol_ring=Chem.MolFromSmiles('c1ccccc1')
img_ring=Draw.MolToImage(mol_ring)
display(img_ring)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_ring2=Chem.MolFromSmiles('c1cc2ccccc2cc1')
img_ring2=Draw.MolToImage(mol_ring2)
display(img_ring2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_ring3=Chem.MolFromSmiles('C1OC1CC')
img_ring3=Draw.MolToImage(mol_ring3)
display(img_ring3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_charge=Chem.MolFromSmiles("[n+]1ccccc1CC(=O)")
img_charge=Draw.MolToImage(mol_charge)
display(img_charge)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_charge2=Chem.MolFromSmiles('CCC(=O)[O-]')
img_charge2=Draw.MolToImage(mol_charge2)
display(img_charge2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
